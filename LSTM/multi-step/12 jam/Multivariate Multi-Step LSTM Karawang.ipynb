# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# load and clean-up data
from numpy import nan
from pandas import read_csv
# univariate multi-step lstm
# import library 
from math import sqrt
from numpy import split
from numpy import array
from pandas import read_csv
from sklearn.metrics import mean_squared_error
from matplotlib import pyplot
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## Preparing Data

# %%
# read data
data = pd.read_excel(r'/content/drive/MyDrive/TA (1)/Processing Data/Data/raw data/data_after_cleansing.xlsx',sheet_name="Karawang")
data
# Out:
#                     Date  Hours  Hs [m]  Angin [m/s]
# 0    1999-01-12 00:00:00      1   0.281     3.450012
# 1    1999-01-12 01:00:00      2   0.281     3.195916
# 2    1999-01-12 02:00:00      3   0.281     3.480425
# 3    1999-01-12 03:00:00      4   0.234     3.734589
# 4    1999-01-12 04:00:00      5   0.234     3.478974
# ...                  ...    ...     ...          ...
# 3643 1999-06-12 19:00:00   3644   0.297     4.675316
# 3644 1999-06-12 20:00:00   3645   0.297     4.597948
# 3645 1999-06-12 21:00:00   3646   0.250     4.480365
# 3646 1999-06-12 22:00:00   3647   0.250     4.327907
# 3647 1999-06-12 23:00:00   3648   0.250     4.653177
#
# [3648 rows x 4 columns]

# %%
# plotting raw data
plt.plot(data['Hours'],data['Hs [m]'])
plt.show()

# %%
import copy
data_raw = copy.deepcopy(data)

# %% [markdown]
# ### handling outliers

# %%
data['Hs [m]'].plot(kind='box', sharex=False, sharey=False)
plt.show()

# %%
# calculate q1, q3, iqr 
q1 = data['Hs [m]'].quantile(0.25)
q3 = data['Hs [m]'].quantile(0.75)
iqr = q3 - q1

# %%
data['Hs [m]'].loc[(data['Hs [m]']> q3+(1.5*iqr)) & (data['Hs [m]']<= q3+(3*iqr)) ]
# Out:
# 624     1.828
# 625     1.828
# 626     1.828
# 627     1.922
# 628     1.922
# 629     1.922
# 630     1.734
# 631     1.734
# 632     1.734
# 633     1.406
# 634     1.406
# 635     1.406
# 648     1.852
# 649     1.852
# 650     1.852
# 651     1.875
# 652     1.875
# 653     1.875
# 654     1.805
# 655     1.805
# 656     1.805
# 657     1.406
# 658     1.406
# 659     1.406
# 672     1.641
# 673     1.641
# 674     1.641
# 675     1.383
# 676     1.383
# 677     1.383
# 1449    1.383
# 1450    1.383
# 1451    1.383
# 1497    1.664
# 1498    1.664
# 1499    1.664
# 1500    1.359
# 1501    1.359
# 1502    1.359
# 2049    1.625
# 2050    1.625
# 2051    1.625
# 2277    1.422
# 2278    1.422
# 2279    1.422
# Name: Hs [m], dtype: float64

# %%
# outlier atas
data['Hs [m]'].loc[(data['Hs [m]']> q3+(1.5*iqr)) & (data['Hs [m]']<= q3+(3*iqr)) ] = np.nan

#outlier bawah
data['Hs [m]'].loc[(data['Hs [m]']< q1-(1.5*iqr)) & (data['Hs [m]']>= q1-(3*iqr)) ] = np.nan

# nilai ekstrim bawah
data['Hs [m]'].loc[data['Hs [m]']> q3 + (3*iqr) ] = np.nan

# nilai ekstrim atas
data['Hs [m]'].loc[data['Hs [m]']< q1 - (3*iqr) ] = np.nan
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
data.head()
# Out:
#                  Date  Hours  Hs [m]  Angin [m/s]
# 0 1999-01-12 00:00:00      1   0.281     3.450012
# 1 1999-01-12 01:00:00      2   0.281     3.195916
# 2 1999-01-12 02:00:00      3   0.281     3.480425
# 3 1999-01-12 03:00:00      4   0.234     3.734589
# 4 1999-01-12 04:00:00      5   0.234     3.478974

# %%
plt.subplot(121)
plt.plot(data['Hs [m]'])
plt.title('Without Outliers')

plt.subplot(122)
plt.plot(data_raw['Hs [m]'])
plt.title('With Outliers')

plt.tight_layout()

# %% [markdown]
# ### Interpolation

# %%
# import library
from scipy.interpolate import interp1d
from scipy.interpolate import CubicSpline

# %%
# define other dataframe for interpolate 
data2 = copy.deepcopy(data)
data3 = copy.deepcopy(data)
data4 = copy.deepcopy(data)

# %%
# drop NaN value in dataframe data
data = data.dropna()

# %%
# cubic interpolation
y_fc=interp1d(data['Hours'],data['Hs [m]'], kind='cubic')

# %%
# quadratic interpolation
y_fq=interp1d(data['Hours'],data['Hs [m]'], kind='quadratic')

# %%
y_fc=CubicSpline(data['Hours'],data['Hs [m]'],extrapolate=True)

# %%
# linear interpolation
y_fl=interp1d(data['Hours'],data['Hs [m]'], kind='linear')

# %%
# interpolate using function we define before
import math

for i in data2['Hours'] :
  if math.isnan(data2['Hs [m]'][i-1])== True:
    data2['Hs [m]'][i-1] = y_fc(i)
    data3['Hs [m]'][i-1] = y_fq(i)
    data4['Hs [m]'][i-1] = y_fl(i)
  else:
    pass
#data.loc[data['Hs [m]'].isna()]
# Out:
# <ipython-input-14-86623d2f7eed>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['Hs [m]'][i-1] = y_fc(i)
# <ipython-input-14-86623d2f7eed>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['Hs [m]'][i-1] = y_fq(i)
# <ipython-input-14-86623d2f7eed>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data4['Hs [m]'][i-1] = y_fl(i)

# %%
# plot after interpolation
plt.plot(data2['Hours'],data2['Hs [m]'], label ='cubic')
plt.plot(data3['Hours'],data3['Hs [m]'], label ='quadratic')
plt.plot(data4['Hours'],data4['Hs [m]'], label ='linear')
#plotting scatter point of data
plt.xlabel('Hours')
plt.ylabel('Hs [m]')
plt.legend()
plt.show()

# %%
# plot after interpolation
plt.plot(data2['Hours'],data2['Hs [m]'], label ='cubic')
#plotting scatter point of data
plt.xlabel('Hours')
plt.ylabel('Hs [m]')
plt.legend()
plt.show()

# %%
# plotting wind and wave
# create figure and axis objects with subplots()
fig,ax = plt.subplots(figsize=(20, 10))
# make a plot
ax.plot(data2['Hours'],
        data2['Hs [m]'],
        color="red", 
        )
# set x-axis label
ax.set_xlabel("Hours", fontsize = 14)
# set y-axis label
ax.set_ylabel("Hs [m]",
              color="red",
              fontsize=14)

# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(data2['Hours'],
        data2['Angin [m/s]'],color="blue")
ax2.set_ylabel("Wind Speed [m/s]",color="blue",fontsize=14)
plt.show()

# %% [markdown]
# karena data tidak berdistribusi normal -> ada skew nya (positif) makanya buat scaling data pake -> Normalize Data

# %% [markdown]
# ### splitting data

# %%
data_swh = data2[['Hs [m]','Angin [m/s]']]
type(data_swh), data_swh.shape
# Out:
# (pandas.core.frame.DataFrame, (3648, 2))

# %%
len(data_swh)
# Out:
# 3648

# %%
data_swh[1:5]
# Out:
#    Hs [m]  Angin [m/s]
# 1   0.281     3.195916
# 2   0.281     3.480425
# 3   0.234     3.734589
# 4   0.234     3.478974

# %% [markdown]
# **Pembagian data**
#
# train = data 70% --> 1 - 2556
#
# val = data 10% --> 2557 - 2928
#
# test = data 20% --> 2929 - 3648

# %%
train = data_swh[:2556]
val = data_swh[2556:2928]
test = data_swh[2928:]
train.shape, val.shape, test.shape
# Out:
# ((2556, 2), (372, 2), (720, 2))

# %%
# resturvture into windows of 12 hours data
train = array(split(train, round(len(train)/12)))
val = array(split(val, round(len(val)/12)))
test = array(split(test, round(len(test)/12)))
train.shape, val.shape, test.shape
# Out:
# ((213, 12, 2), (31, 12, 2), (60, 12, 2))

# %%
n_input,n_out = 12,12
data_train = train.reshape((train.shape[0]*train.shape[1],train.shape[2] ))
data_val = val.reshape((val.shape[0]*val.shape[1],train.shape[2] ))
data_train.shape, data_val.shape
# Out:
# ((2556, 2), (372, 2))

# %%
len(data_train)
# Out:
# 2556

# %%
def split_into_xy(sequence, n_steps_in, n_steps_out):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps_in
		out_end_ix = end_ix + n_steps_out
		# check if we are beyond the sequence
		if out_end_ix > len(sequence):
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:out_end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return array(X), array(y)

# %%
n_steps_in, n_steps_out = 12, 12
X_train, y_train = split_into_xy(data_train,n_steps_in, n_steps_out)
X_val, y_val = split_into_xy(data_val,n_steps_in, n_steps_out)
X_train.shape, y_train.shape, X_val.shape, y_val.shape
# Out:
# ((2533, 12, 2), (2533, 12, 2), (349, 12, 2), (349, 12, 2))

# %%
n_features = 2
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], n_features))
X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], n_features))
X_train.shape,X_val.shape
# Out:
# ((2533, 12, 2), (349, 12, 2))

# %%
y_train = y_train[:,:,0].reshape((y_train.shape[0], y_train.shape[1],))
y_val = y_val[:,:,0].reshape((y_val.shape[0], y_val.shape[1],))
y_train.shape,y_val.shape
# Out:
# ((2533, 12), (349, 12))

# %%
yyy
# Out:
# array([[0.422, 0.422, 0.422, ..., 0.188, 0.188, 0.188],
#        [0.422, 0.422, 0.305, ..., 0.188, 0.188, 0.164],
#        [0.422, 0.305, 0.305, ..., 0.188, 0.164, 0.164],
#        ...,
#        [0.391, 0.391, 0.344, ..., 0.328, 0.328, 0.344],
#        [0.391, 0.344, 0.344, ..., 0.328, 0.344, 0.344],
#        [0.344, 0.344, 0.344, ..., 0.344, 0.344, 0.344]])

# %% [markdown]
# ## Model

# %%
n_timesteps, n_features, n_outputs = X_train.shape[1], X_train.shape[2], y_train.shape[1]
# define model
model = Sequential()
model.add(LSTM(200, activation='relu', input_shape=(n_timesteps, n_features)))
model.add(RepeatVector(n_outputs))
model.add(LSTM(200, activation='relu', return_sequences=True))
model.add(TimeDistributed(Dense(100, activation='relu')))
model.add(TimeDistributed(Dense(1)))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 200)               162400
#
#  repeat_vector (RepeatVector  (None, 12, 200)          0
#  )
#
#  lstm_1 (LSTM)               (None, 12, 200)           320800
#
#  time_distributed (TimeDistr  (None, 12, 100)          20100
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 12, 1)            101
#  tributed)
#
# =================================================================
# Total params: 503,401
# Trainable params: 503,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp1 = ModelCheckpoint('model/', save_best_only=True)
model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, callbacks=[cp1])
# Out:
# Epoch 1/100
# 80/80 [==============================] - 12s 114ms/step - loss: 0.0325 - root_mean_squared_error: 0.1804 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0871
# Epoch 2/100
# 80/80 [==============================] - 8s 101ms/step - loss: 0.0320 - root_mean_squared_error: 0.1790 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0845
# Epoch 3/100
# 80/80 [==============================] - 7s 88ms/step - loss: 0.0319 - root_mean_squared_error: 0.1785 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1020
# Epoch 4/100
# 80/80 [==============================] - 7s 82ms/step - loss: 0.0320 - root_mean_squared_error: 0.1790 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0824
# Epoch 5/100
# 80/80 [==============================] - 8s 94ms/step - loss: 0.0317 - root_mean_squared_error: 0.1781 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0808
# Epoch 6/100
# 80/80 [==============================] - 6s 75ms/step - loss: 0.0314 - root_mean_squared_error: 0.1772 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1070
# Epoch 7/100
# 80/80 [==============================] - 8s 95ms/step - loss: 0.0323 - root_mean_squared_error: 0.1797 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0821
# Epoch 8/100
# 80/80 [==============================] - 6s 75ms/step - loss: 0.0312 - root_mean_squared_error: 0.1766 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0853
# Epoch 9/100
# 80/80 [==============================] - 9s 112ms/step - loss: 0.0307 - root_mean_squared_error: 0.1752 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0906
# Epoch 10/100
# 80/80 [==============================] - 7s 84ms/step - loss: 0.0313 - root_mean_squared_error: 0.1771 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0844
# Epoch 11/100
# 80/80 [==============================] - 8s 99ms/step - loss: 0.0314 - root_mean_squared_error: 0.1773 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0826
# Epoch 12/100
# 80/80 [==============================] - 6s 75ms/step - loss: 0.0306 - root_mean_squared_error: 0.1750 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0875
# Epoch 13/100
# 80/80 [==============================] - 8s 97ms/step - loss: 0.0308 - root_mean_squared_error: 0.1754 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0995
# Epoch 14/100
# 80/80 [==============================] - 6s 76ms/step - loss: 0.0311 - root_mean_squared_error: 0.1765 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0973
# Epoch 15/100
# 80/80 [==============================] - 8s 98ms/step - loss: 0.0311 - root_mean_squared_error: 0.1764 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0817
# Epoch 16/100
# 80/80 [==============================] - 6s 75ms/step - loss: 0.0303 - root_mean_squared_error: 0.1742 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0887
# Epoch 17/100
# 80/80 [==============================] - 8s 101ms/step - loss: 0.0300 - root_mean_squared_error: 0.1733 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0896
# Epoch 18/100
# 80/80 [==============================] - 8s 97ms/step - loss: 0.0302 - root_mean_squared_error: 0.1738 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0872
# Epoch 19/100
# 80/80 [==============================] - 6s 80ms/step - loss: 0.0308 - root_mean_squared_error: 0.1756 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0812
# Epoch 20/100
# 80/80 [==============================] - 7s 92ms/step - loss: 0.0301 - root_mean_squared_error: 0.1734 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1122
# Epoch 21/100
# 80/80 [==============================] - 6s 75ms/step - loss: 0.0305 - root_mean_squared_error: 0.1747 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0871
# Epoch 22/100
# 80/80 [==============================] - 8s 96ms/step - loss: 0.0299 - root_mean_squared_error: 0.1728 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0876
# Epoch 23/100
# 80/80 [==============================] - 6s 75ms/step - loss: 0.0296 - root_mean_squared_error: 0.1721 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0819
# Epoch 24/100
# 80/80 [==============================] - 8s 97ms/step - loss: 0.0292 - root_mean_squared_error: 0.1710 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1035
# Epoch 25/100
# 80/80 [==============================] - 8s 96ms/step - loss: 0.0298 - root_mean_squared_error: 0.1726 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0848
# Epoch 26/100
# 80/80 [==============================] - 8s 98ms/step - loss: 0.0298 - root_mean_squared_error: 0.1725 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0873
# Epoch 27/100
# 80/80 [==============================] - 6s 77ms/step - loss: 0.0285 - root_mean_squared_error: 0.1687 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0976
# Epoch 28/100
# 80/80 [==============================] - 8s 97ms/step - loss: 0.0286 - root_mean_squared_error: 0.1692 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0831
# Epoch 29/100
# 80/80 [==============================] - 6s 75ms/step - loss: 0.0287 - root_mean_squared_error: 0.1693 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0853
# Epoch 30/100
# 80/80 [==============================] - 8s 97ms/step - loss: 0.0285 - root_mean_squared_error: 0.1688 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0872
# Epoch 31/100
# 80/80 [==============================] - 6s 76ms/step - loss: 0.0283 - root_mean_squared_error: 0.1683 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0910
# Epoch 32/100
# 80/80 [==============================] - 8s 99ms/step - loss: 0.0286 - root_mean_squared_error: 0.1692 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0846
# Epoch 33/100
# 80/80 [==============================] - 8s 99ms/step - loss: 0.0300 - root_mean_squared_error: 0.1732 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0836
# Epoch 34/100
# 80/80 [==============================] - 8s 100ms/step - loss: 0.0281 - root_mean_squared_error: 0.1676 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0835
# Epoch 35/100
# 80/80 [==============================] - 6s 78ms/step - loss: 0.0284 - root_mean_squared_error: 0.1686 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0925
# Epoch 36/100
# 80/80 [==============================] - 8s 101ms/step - loss: 0.0289 - root_mean_squared_error: 0.1700 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0868
# Epoch 37/100
# 80/80 [==============================] - 6s 77ms/step - loss: 0.0280 - root_mean_squared_error: 0.1672 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1013
# Epoch 38/100
# 80/80 [==============================] - 8s 98ms/step - loss: 0.0284 - root_mean_squared_error: 0.1686 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0822
# Epoch 39/100
# 80/80 [==============================] - 6s 76ms/step - loss: 0.0277 - root_mean_squared_error: 0.1666 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0879
# Epoch 40/100
# 80/80 [==============================] - 7s 92ms/step - loss: 0.0276 - root_mean_squared_error: 0.1661 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0892
# Epoch 41/100
# 80/80 [==============================] - 8s 103ms/step - loss: 0.0279 - root_mean_squared_error: 0.1669 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0900
# Epoch 42/100
# 80/80 [==============================] - 8s 99ms/step - loss: 0.0280 - root_mean_squared_error: 0.1673 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1074
# Epoch 43/100
# 80/80 [==============================] - 6s 74ms/step - loss: 0.0276 - root_mean_squared_error: 0.1661 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0866
# Epoch 44/100
# 80/80 [==============================] - 8s 97ms/step - loss: 0.0275 - root_mean_squared_error: 0.1657 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0903
# Epoch 45/100
# 80/80 [==============================] - 6s 79ms/step - loss: 0.0275 - root_mean_squared_error: 0.1657 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1015
# Epoch 46/100
# 80/80 [==============================] - 7s 93ms/step - loss: 0.0266 - root_mean_squared_error: 0.1629 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0901
# Epoch 47/100
# 80/80 [==============================] - 6s 81ms/step - loss: 0.0268 - root_mean_squared_error: 0.1639 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0924
# Epoch 48/100
# 80/80 [==============================] - 7s 87ms/step - loss: 0.0274 - root_mean_squared_error: 0.1655 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0983
# Epoch 49/100
# 80/80 [==============================] - 9s 110ms/step - loss: 0.0269 - root_mean_squared_error: 0.1640 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0902
# Epoch 50/100
# 80/80 [==============================] - 6s 81ms/step - loss: 0.0271 - root_mean_squared_error: 0.1647 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0934
# Epoch 51/100
# 80/80 [==============================] - 7s 92ms/step - loss: 0.0262 - root_mean_squared_error: 0.1620 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0859
# Epoch 52/100
# 80/80 [==============================] - 7s 82ms/step - loss: 0.0282 - root_mean_squared_error: 0.1680 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0887
# Epoch 53/100
# 80/80 [==============================] - 8s 95ms/step - loss: 0.0269 - root_mean_squared_error: 0.1641 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0954
# Epoch 54/100
# 80/80 [==============================] - 7s 88ms/step - loss: 0.0257 - root_mean_squared_error: 0.1603 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0874
# Epoch 55/100
# 80/80 [==============================] - 8s 96ms/step - loss: 0.0259 - root_mean_squared_error: 0.1608 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0943
# Epoch 56/100
# 80/80 [==============================] - 7s 87ms/step - loss: 0.0264 - root_mean_squared_error: 0.1625 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0992
# Epoch 57/100
# 80/80 [==============================] - 9s 111ms/step - loss: 0.0257 - root_mean_squared_error: 0.1602 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0938
# Epoch 58/100
# 80/80 [==============================] - 6s 74ms/step - loss: 0.0251 - root_mean_squared_error: 0.1583 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0917
# Epoch 59/100
# 80/80 [==============================] - 8s 99ms/step - loss: 0.0252 - root_mean_squared_error: 0.1589 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1042
# Epoch 60/100
# 80/80 [==============================] - 6s 75ms/step - loss: 0.0256 - root_mean_squared_error: 0.1599 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0985
# Epoch 61/100
# 80/80 [==============================] - 8s 98ms/step - loss: 0.0252 - root_mean_squared_error: 0.1588 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1052
# Epoch 62/100
# 80/80 [==============================] - 6s 76ms/step - loss: 0.0254 - root_mean_squared_error: 0.1594 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1012
# Epoch 63/100
# 80/80 [==============================] - 8s 97ms/step - loss: 0.0250 - root_mean_squared_error: 0.1581 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1016
# Epoch 64/100
# 80/80 [==============================] - 7s 86ms/step - loss: 0.0251 - root_mean_squared_error: 0.1583 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1153
# Epoch 65/100
# 80/80 [==============================] - 9s 111ms/step - loss: 0.0246 - root_mean_squared_error: 0.1568 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0988
# Epoch 66/100
# 80/80 [==============================] - 6s 75ms/step - loss: 0.0251 - root_mean_squared_error: 0.1584 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1019
# Epoch 67/100
# 80/80 [==============================] - 8s 96ms/step - loss: 0.0257 - root_mean_squared_error: 0.1605 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0967
# Epoch 68/100
# 80/80 [==============================] - 6s 75ms/step - loss: 0.0255 - root_mean_squared_error: 0.1598 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0995
# Epoch 69/100
# 80/80 [==============================] - 7s 89ms/step - loss: 0.0248 - root_mean_squared_error: 0.1576 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1121
# Epoch 70/100
# 80/80 [==============================] - 7s 85ms/step - loss: 0.0246 - root_mean_squared_error: 0.1567 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0974
# Epoch 71/100
# 80/80 [==============================] - 7s 86ms/step - loss: 0.0239 - root_mean_squared_error: 0.1545 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1026
# Epoch 72/100
# 80/80 [==============================] - 9s 107ms/step - loss: 0.0244 - root_mean_squared_error: 0.1563 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1105
# Epoch 73/100
# 80/80 [==============================] - 8s 102ms/step - loss: 0.0241 - root_mean_squared_error: 0.1553 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1099
# Epoch 74/100
# 80/80 [==============================] - 6s 77ms/step - loss: 0.0234 - root_mean_squared_error: 0.1528 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1127
# Epoch 75/100
# 80/80 [==============================] - 7s 89ms/step - loss: 0.0241 - root_mean_squared_error: 0.1554 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1051
# Epoch 76/100
# 80/80 [==============================] - 7s 85ms/step - loss: 0.0235 - root_mean_squared_error: 0.1534 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1075
# Epoch 77/100
# 80/80 [==============================] - 7s 84ms/step - loss: 0.0239 - root_mean_squared_error: 0.1546 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1088
# Epoch 78/100
# 80/80 [==============================] - 7s 89ms/step - loss: 0.0234 - root_mean_squared_error: 0.1528 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1090
# Epoch 79/100
# 80/80 [==============================] - 6s 81ms/step - loss: 0.0232 - root_mean_squared_error: 0.1523 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1249
# Epoch 80/100
# 80/80 [==============================] - 9s 117ms/step - loss: 0.0229 - root_mean_squared_error: 0.1513 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1055
# Epoch 81/100
# 80/80 [==============================] - 7s 91ms/step - loss: 0.0233 - root_mean_squared_error: 0.1525 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1120
# Epoch 82/100
# 80/80 [==============================] - 7s 85ms/step - loss: 0.0228 - root_mean_squared_error: 0.1510 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1113
# Epoch 83/100
# 80/80 [==============================] - 7s 85ms/step - loss: 0.0224 - root_mean_squared_error: 0.1497 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1171
# Epoch 84/100
# 80/80 [==============================] - 7s 88ms/step - loss: 0.0230 - root_mean_squared_error: 0.1518 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1108
# Epoch 85/100
# 80/80 [==============================] - 6s 80ms/step - loss: 0.0225 - root_mean_squared_error: 0.1499 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1062
# Epoch 86/100
# 80/80 [==============================] - 8s 93ms/step - loss: 0.0232 - root_mean_squared_error: 0.1524 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1109
# Epoch 87/100
# 80/80 [==============================] - 6s 76ms/step - loss: 0.0222 - root_mean_squared_error: 0.1490 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1119
# Epoch 88/100
# 80/80 [==============================] - 10s 124ms/step - loss: 0.0226 - root_mean_squared_error: 0.1504 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1175
# Epoch 89/100
# 80/80 [==============================] - 6s 75ms/step - loss: 0.0220 - root_mean_squared_error: 0.1483 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1111
# Epoch 90/100
# 80/80 [==============================] - 8s 101ms/step - loss: 0.0221 - root_mean_squared_error: 0.1488 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1159
# Epoch 91/100
# 80/80 [==============================] - 6s 76ms/step - loss: 0.0212 - root_mean_squared_error: 0.1456 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1124
# Epoch 92/100
# 80/80 [==============================] - 8s 98ms/step - loss: 0.0210 - root_mean_squared_error: 0.1450 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1247
# Epoch 93/100
# 80/80 [==============================] - 6s 75ms/step - loss: 0.0210 - root_mean_squared_error: 0.1448 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1202
# Epoch 94/100
# 80/80 [==============================] - 8s 99ms/step - loss: 0.0217 - root_mean_squared_error: 0.1473 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1117
# Epoch 95/100
# 80/80 [==============================] - 6s 77ms/step - loss: 0.0213 - root_mean_squared_error: 0.1459 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1148
# Epoch 96/100
# 80/80 [==============================] - 10s 121ms/step - loss: 0.0211 - root_mean_squared_error: 0.1453 - val_loss: 0.0201 - val_root_mean_squared_error: 0.1416
# Epoch 97/100
# 80/80 [==============================] - 6s 80ms/step - loss: 0.0210 - root_mean_squared_error: 0.1449 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1180
# Epoch 98/100
# 80/80 [==============================] - 7s 90ms/step - loss: 0.0224 - root_mean_squared_error: 0.1497 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1239
# Epoch 99/100
# 80/80 [==============================] - 7s 86ms/step - loss: 0.0221 - root_mean_squared_error: 0.1486 - val_loss: 0.0161 - val_root_mean_squared_error: 0.1268
# Epoch 100/100
# 80/80 [==============================] - 7s 82ms/step - loss: 0.0216 - root_mean_squared_error: 0.1470 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1202

# %%
from tensorflow.keras.models import load_model
model = load_model('model/')

# %%
history = [x for x in val]
predictions = list()
for i in range(len(test)):
  data = array(history)
  data = data.reshape((data.shape[0]*data.shape[1], data.shape[2]))
  input_x = data[-n_input:,: ]
  input_x = input_x.reshape((1, len(input_x), 2))
  # predict the week
  yhat = model.predict(input_x, verbose=0)
  yhat_sequence = yhat[0]
  # store the predictions
  predictions.append(yhat_sequence)
  # get real observation and add to history for predicting the next week
  history.append(test[i, :])

# %%
array(predictions).shape
# Out:
# (60, 12, 1)

# %%
prediksi = array(predictions)
observasi = test[:,:,0]
prediksi = prediksi.reshape((prediksi.shape[0]*prediksi.shape[1], 1))
observasi = observasi.reshape((observasi.shape[0]*observasi.shape[1], 1))

# %%
import pandas as pd
test_results = pd.DataFrame(data={'Univariate':prediksi.flatten(), 
                                   'Actuals':observasi.flatten()})
test_results
# Out:
#      Univariate   Actuals
# 0      0.577574  0.577203
# 1      0.592379  0.581304
# 2      0.575498  0.585453
# 3      0.562733  0.589647
# 4      0.553176  0.593886
# ..          ...       ...
# 715    0.454126  0.297000
# 716    0.457242  0.297000
# 717    0.459514  0.250000
# 718    0.461719  0.250000
# 719    0.464464  0.250000
#
# [720 rows x 2 columns]

# %%
test_results['Date'] = data2['Date'].iloc[2928:].values
test_results.head()
# Out:
#    Univariate   Actuals                Date
# 0    0.577574  0.577203 1999-05-14 00:00:00
# 1    0.592379  0.581304 1999-05-14 01:00:00
# 2    0.575498  0.585453 1999-05-14 02:00:00
# 3    0.562733  0.589647 1999-05-14 03:00:00
# 4    0.553176  0.593886 1999-05-14 04:00:00

# %%
plt.plot(test_results['Univariate'])
plt.plot(test_results['Actuals'])

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig = go.Figure()
fig.add_trace(go.Scatter(x=test_results['Date'], y=test_results['Univariate'],
                    mode='lines',
                    name='Fitting Data Testing'))
fig.add_trace(go.Scatter(x=test_results['Date'], y=test_results['Actuals'],
                    mode='lines',fillcolor='#ff0000',
                    name='Observation'))

# Edit the layout
fig.update_layout( xaxis_title='<b>Date</b>',
                   yaxis_title='<b><i>Hs</i> [m]</b>')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e50651f6-b719-4715-89d7-b80e47a748cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e50651f6-b719-4715-89d7-b80e47a748cc")) {                    Plotly.newPlot(                        "e50651f6-b719-4715-89d7-b80e47a748cc",                        [{"mode":"lines","name":"Fitting Data Testing","x":["1999-05-14T00:00:00","1999-05-14T01:00:00","1999-05-14T02:00:00","1999-05-14T03:00:00","1999-05-14T04:00:00","1999-05-14T05:00:00","1999-05-14T06:00:00","1999-05-14T07:00:00","1999-05-14T08:00:00","1999-05-14T09:00:00","1999-05-14T10:00:00","1999-05-14T11:00:00","1999-05-14T12:00:00","1999-05-14T13:00:00","1999-05-14T14:00:00","1999-05-14T15:00:00","1999-05-14T16:00:00","1999-05-14T17:00:00","1999-05-14T18:00:00","1999-05-14T19:00:00","1999-05-14T20:00:00","1999-05-14T21:00:00","1999-05-14T22:00:00","1999-05-14T23:00:00","1999-05-15T00:00:00","1999-05-15T01:00:00","1999-05-15T02:00:00","1999-05-15T03:00:00","1999-05-15T04:00:00","1999-05-15T05:00:00","1999-05-15T06:00:00","1999-05-15T07:00:00","1999-05-15T08:00:00","1999-05-15T09:00:00","1999-05-15T10:00:00","1999-05-15T11:00:00","1999-05-15T12:00:00","1999-05-15T13:00:00","1999-05-15T14:00:00","1999-05-15T15:00:00","1999-05-15T16:00:00","1999-05-15T17:00:00","1999-05-15T18:00:00","1999-05-15T19:00:00","1999-05-15T20:00:00","1999-05-15T21:00:00","1999-05-15T22:00:00","1999-05-15T23:00:00","1999-05-16T00:00:00","1999-05-16T01:00:00","1999-05-16T02:00:00","1999-05-16T03:00:00","1999-05-16T04:00:00","1999-05-16T05:00:00","1999-05-16T06:00:00","1999-05-16T07:00:00","1999-05-16T08:00:00","1999-05-16T09:00:00","1999-05-16T10:00:00","1999-05-16T11:00:00","1999-05-16T12:00:00","1999-05-16T13:00:00","1999-05-16T14:00:00","1999-05-16T15:00:00","1999-05-16T16:00:00","1999-05-16T17:00:00","1999-05-16T18:00:00","1999-05-16T19:00:00","1999-05-16T20:00:00","1999-05-16T21:00:00","1999-05-16T22:00:00","1999-05-16T23:00:00","1999-05-17T00:00:00","1999-05-17T01:00:00","1999-05-17T02:00:00","1999-05-17T03:00:00","1999-05-17T04:00:00","1999-05-17T05:00:00","1999-05-17T06:00:00","1999-05-17T07:00:00","1999-05-17T08:00:00","1999-05-17T09:00:00","1999-05-17T10:00:00","1999-05-17T11:00:00","1999-05-17T12:00:00","1999-05-17T13:00:00","1999-05-17T14:00:00","1999-05-17T15:00:00","1999-05-17T16:00:00","1999-05-17T17:00:00","1999-05-17T18:00:00","1999-05-17T19:00:00","1999-05-17T20:00:00","1999-05-17T21:00:00","1999-05-17T22:00:00","1999-05-17T23:00:00","1999-05-18T00:00:00","1999-05-18T01:00:00","1999-05-18T02:00:00","1999-05-18T03:00:00","1999-05-18T04:00:00","1999-05-18T05:00:00","1999-05-18T06:00:00","1999-05-18T07:00:00","1999-05-18T08:00:00","1999-05-18T09:00:00","1999-05-18T10:00:00","1999-05-18T11:00:00","1999-05-18T12:00:00","1999-05-18T13:00:00","1999-05-18T14:00:00","1999-05-18T15:00:00","1999-05-18T16:00:00","1999-05-18T17:00:00","1999-05-18T18:00:00","1999-05-18T19:00:00","1999-05-18T20:00:00","1999-05-18T21:00:00","1999-05-18T22:00:00","1999-05-18T23:00:00","1999-05-19T00:00:00","1999-05-19T01:00:00","1999-05-19T02:00:00","1999-05-19T03:00:00","1999-05-19T04:00:00","1999-05-19T05:00:00","1999-05-19T06:00:00","1999-05-19T07:00:00","1999-05-19T08:00:00","1999-05-19T09:00:00","1999-05-19T10:00:00","1999-05-19T11:00:00","1999-05-19T12:00:00","1999-05-19T13:00:00","1999-05-19T14:00:00","1999-05-19T15:00:00","1999-05-19T16:00:00","1999-05-19T17:00:00","1999-05-19T18:00:00","1999-05-19T19:00:00","1999-05-19T20:00:00","1999-05-19T21:00:00","1999-05-19T22:00:00","1999-05-19T23:00:00","1999-05-20T00:00:00","1999-05-20T01:00:00","1999-05-20T02:00:00","1999-05-20T03:00:00","1999-05-20T04:00:00","1999-05-20T05:00:00","1999-05-20T06:00:00","1999-05-20T07:00:00","1999-05-20T08:00:00","1999-05-20T09:00:00","1999-05-20T10 ...

# %%
from sklearn.metrics import mean_squared_error
import math

MSE = mean_squared_error(test_results['Actuals'],test_results['Univariate'])
RMSE = math.sqrt(MSE)
RMSE
# Out:
# 0.09510007822632802

# %%
from scipy.stats import pearsonr
corr, _ = pearsonr(test_results['Actuals'],test_results['Univariate'])
corr
# Out:
# 0.8948027510292623

# %%
# bias 
gap_sum = 0
for j in range(len(test_results['Actuals'])):
  gap = test_results['Univariate'][j] - test_results['Actuals'][j]
  gap_sum += gap

bias = gap_sum/len(test_results['Actuals'])
bias
# Out:
# -0.006238714821325378

# %%
test_results.to_csv('/content/drive/MyDrive/TA (1)/Learn to Code ML/Hasil Prediksi /multi-step/multivariate_12jam_lstm_karawang.csv')
